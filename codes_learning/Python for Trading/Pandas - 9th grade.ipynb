# %% [markdown]
# ## Pandas Data Types

# %% [markdown]
# <div>
# There are two core objects in pandas: <b> the DataFrame </b> and <b>the Series</b>.
# </div>

# %%
import pandas as pd

# %% [markdown]
# ### DataFrame

# %% [markdown]
# <div>
#     A DataFrame is a table. It contains an array of individual entries, each with a certain value.<br> Each entry corresponds to a row and a column.
# </div>

# %% [markdown]
# <i>
#     pd.DataFrame( A Dictionary(keys->column names), (optional)index= (row names) )
# </i>

# %%
dict1 = {'eggs': [{'A':12},{'B':5, 'C':8},{}], 'orange': [13, 17, 19], 'horse':23, 'temp':(1, 2, 3)}
list1 = ['week1', 'week2', 'week3']
df1 = pd.DataFrame(dict1, index=list1)
df1
# Out:
#                    eggs  orange  horse  temp
# week1         {'A': 12}      13     23     1
# week2  {'B': 5, 'C': 8}      17     23     2
# week3                {}      19     23     3

# %%
list2 = ( [12, 14, 17, 27], [22, 32, 42, 52], (1, 2, 3, 4))

pd.DataFrame(list2, columns=['A', 'B', 'C', 'D'], index= list1)
# Out:
#         A   B   C   D
# week1  12  14  17  27
# week2  22  32  42  52
# week3   1   2   3   4

# %%
pd.DataFrame(dict1,columns=['A', 'B', 'C', 'D'], index=(4,5))
# Out:
#      A    B    C    D
# 4  NaN  NaN  NaN  NaN
# 5  NaN  NaN  NaN  NaN

# %% [markdown]
# ### Series

# %% [markdown]
# <div>
#     A Series is, in essence, a single column of a DataFrame.
#     <br> However, a Series does not have a column name, it only has one overall "name".
# </div>

# %% [markdown]
# <i>pd.Series( list/tuple/... ,(optional) index= (row names), (optional) name)</i>

# %%
pd.Series(list1, index=['day1', 'day2', 'day3'], name='random')
# Out:
# day1    week1
# day2    week2
# day3    week3
# Name: random, dtype: object

# %%
pd.Series(dict1)
# Out:
# eggs      [{'A': 12}, {'B': 5, 'C': 8}, {}]
# orange                         [13, 17, 19]
# horse                                    23
# temp                              (1, 2, 3)
# dtype: object

# %% [markdown]
# Exercise

# %%
scores = {'Amir':[12, 15, 17] ,'Mani':[20 ,22, 18], 'Arad':[15, 20, 16], 'Reza':[18, 16, 14]}
courses = ["Math", "Physics", "Chemistry"]

df1 = pd.DataFrame(scores, index= courses)

# %% [markdown]
# ## Working With Files

# %% [markdown]
# Data can be stored in any of a number of different forms and formats. By far the most basic of these is the humble CSV file.<br> a CSV file is a table of values separated by commas. Hence the name: "Comma-Separated Values", or CSV.

# %% [markdown]
# <i>reviews = pd.read_csv("Address.csv", (optional) index_col= (index/column_name))</i>

# %% [markdown]
#                  df.shape         df.head(numOfRows) default=5         df.tail(numOfRows) default=5

# %%
df = pd.read_csv("football_players_2019.csv", index_col=0)
df
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.org/flags/52.png       94         94
# 1      https://cdn.sofifa.org/flags/38.png       94         94
# 2      https://cdn.sofifa.org/flags/54.png       92         93
# 3      https://cdn.sofifa.org/flags/45.png       91         93
# 4       https://cdn.sofifa.org/flags/7.png       91         92
# ...                                    ...      ...        ...
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# 18205  https://cdn.sofifa.org/flags/14.png       47         66
# 18206  https://cdn.sofifa.org/flags/14.png       46         66
#
#                       Club                                       Club Logo  \
# 0             FC Barcelona    https://cdn.sofifa.org/teams/2/light/241.png
# 1                 Juventus     https://cdn.sofifa.org/teams/2/light/45.png
# 2      Paris Saint-Germain     https://cdn.sofifa.org/teams/2/light/73.png
# 3        Manchester United     https://cdn.sofifa.org/teams/2/light/11.png
# 4          Manchester City     https://cdn.sofifa.org/teams/2/light/10.png
# ...                    ...                                             ...
# 18202      Crewe Alexandra    https://cdn.sofifa.org/teams/2/light/121.png
# 18203       Trelleborgs FF    https://cdn.sofifa.org/teams/2/light/703.png
# 18204     Cambridge United   https://cdn.sofifa.org/teams/2/light/1944.png
# 18205      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
# 18206      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
#
#        ... Composure Marking  StandingTackle SlidingTackle  GKDiving  \
# 0      ...      96.0    33.0            28.0          26.0       6.0
# 1      ...      95.0    28.0            31.0          23.0       7.0
# 2      ...      94.0    27.0            24.0          33.0       9.0
# 3      ...      68.0    15.0            21.0          13.0      90.0
# 4      ...      88.0    68.0            58.0          51.0      15.0
# ...    ...       ...     ...             ...           ...       ...
# 18202  ...      45.0    40.0            48.0          47.0      10.0
# 18203  ...      42.0    22.0            15.0          19.0      10.0
# 18204  ...      41.0    32.0            13.0          11.0       6.0
# 18205  ...      46.0    20.0            25.0          27.0      14.0
# 18206  ...      43.0    40.0            43.0          50.0      10.0
#
#        GKHandling  GKKicking GKPositioning GKReflexes Release Clause
# 0            11.0       15.0          14.0        8.0        €226.5M
# 1            11.0       15.0          14.0       11.0        €127.1M
# 2             9.0       15.0          15.0       11.0        €228.1M
# 3            85.0       87.0          88.0       94.0        €138.6M
# 4            13.0        5.0          10.0       13.0        €196.4M
# ...           ...        ...           ...        ...            ...
# 18202        13.0        7.0           8.0        9.0          €143K
# 18203         9.0        9.0           5.0       12.0          €113K
# 18204         5.0       10.0           6.0       13.0          €165K
# 18205         6.0       14.0           8.0        9.0          €143K
# 18206        15.0        9.0          12.0        9.0          €165K
#
# [18207 rows x 88 columns]

# %%
df.shape
# Out:
# (18207, 88)

# %%
df.head(14)
# Out:
#         ID               Name  Age  \
# 0   158023           L. Messi   31
# 1    20801  Cristiano Ronaldo   33
# 2   190871          Neymar Jr   26
# 3   193080             De Gea   27
# 4   192985       K. De Bruyne   27
# 5   183277          E. Hazard   27
# 6   177003          L. Modrić   32
# 7   176580          L. Suárez   31
# 8   155862       Sergio Ramos   32
# 9   200389           J. Oblak   25
# 10  188545     R. Lewandowski   29
# 11  182521           T. Kroos   28
# 12  182493           D. Godín   32
# 13  168542        David Silva   32
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2   https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3   https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4   https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5   https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6   https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7   https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# 8   https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 9   https://cdn.sofifa.org/players/4/19/200389.png    Slovenia
# 10  https://cdn.sofifa.org/players/4/19/188545.png      Poland
# 11  https://cdn.sofifa.org/players/4/19/182521.png     Germany
# 12  https://cdn.sofifa.org/players/4/19/182493.png     Uruguay
# 13  https://cdn.sofifa.org/players/4/19/168542.png       Spain
#
#                                    Flag  Overall  Potential  \
# 0   https://cdn.sofifa.org/flags/52.png       94         94
# 1   https://cdn.sofifa.org/flags/38.png       94         94
# 2   https://cdn.sofifa.org/flags/54.png       92         93
# 3   https://cdn.sofifa.org/flags/45.png       91         93
# 4    https://cdn.sofifa.org/flags/7.png       91         92
# 5    https://cdn.sofifa.org/flags/7.png       91         91
# 6   https://cdn.sofifa.org/flags/10.png       91         91
# 7   https://cdn.sofifa.org/flags/60.png       91         91
# 8   https://cdn.sofifa.org/flags/45.png       91         91
# 9   https://cdn.sofifa.org/flags/44.png       90         93
# 10  https://cdn.sofifa.org/flags/37.png       90         90
# 11  https://cdn.sofifa.org/flags/21.png       90         90
# 12  https://cdn.sofifa.org/flags/60.png       90         90
# 13  https://cdn.sofifa.org/flags/45.png       90         90
#
#                    Club                                     Club Logo  ...  \
# 0          FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
# 1              Juventus   https://cdn.sofifa.org/teams/2/light/45.png  ...
# 2   Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  ...
# 3     Manchester United   https://cdn.sofifa.org/teams/2/light/11.png  ...
# 4       Manchester City   https://cdn.sofifa.org/teams/2/light/10.png  ...
# 5               Chelsea    https://cdn.sofifa.org/teams/2/light/5.png  ...
# 6           Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png  ...
# 7          FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
# 8           Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png  ...
# 9       Atlético Madrid  https://cdn.sofifa.org/teams/2/light/240.png  ...
# 10    FC Bayern München   https://cdn.sofifa.org/teams/2/light/21.png  ...
# 11          Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png  ...
# 12      Atlético Madrid  https://cdn.sofifa.org/teams/2/light/240.png  ...
# 13      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png  ...
#
#    Composure Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  \
# 0       96.0    33.0            28.0          26.0       6.0        11.0
# 1       95.0    28.0            31.0          23.0       7.0        11.0
# 2       94.0    27.0            24.0          33.0       9.0         9.0
# 3       68.0    15.0            21.0          13.0      90.0        85.0
# 4       88.0    68.0            58.0          51.0      15.0        13.0
# 5       91.0    34.0            27.0          22.0      11.0        12.0
# 6       84.0    60.0            76.0          73.0      13.0         9.0
# 7       85.0    62.0            45.0          38.0      27.0        25.0
# 8       82.0    87.0            92.0          91.0      11.0         8.0
# 9       70.0    27.0            12.0          18.0      86.0        92.0
# 10      86.0    34.0            42.0          19.0      15.0         6.0
# 11      85.0    72.0            79.0          69.0      10.0        11.0
# 12      82.0    90.0            89.0          89.0       6.0         8.0
# 13      93.0    59.0            53.0          29.0       6.0        15.0
#
#     GKKicking GKPositioning GKReflexes Release Clause
# 0        15.0          14.0        8.0        €226.5M
# 1        15.0          14.0       11.0        €127.1M
# 2        15.0          15.0       11.0        €228.1M
# 3        87.0          88.0       94.0        €138.6M
# 4         5.0          10.0       13.0        €196.4M
# 5         6.0           8.0        8.0        €172.1M
# 6         7.0          14.0        9.0        €137.4M
# 7        31.0          33.0       37.0          €164M
# 8         9.0           7.0       11.0        €104.6M
# 9        78.0          88.0       89.0        €144.5M
# 10       12.0           8.0       10.0        €127.1M
# 11       13.0           7.0       10.0        €156.8M
# 12       15.0           5.0       15.0         €90.2M
# 13        7.0           6.0       12.0          €111M
#
# [14 rows x 88 columns]

# %%
df.tail(7)
# Out:
#            ID                Name  Age  \
# 18200  231381            J. Young   18
# 18201  243413            D. Walsh   18
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo          Nationality  \
# 18200  https://cdn.sofifa.org/players/4/19/231381.png             Scotland
# 18201  https://cdn.sofifa.org/players/4/19/243413.png  Republic of Ireland
# 18202  https://cdn.sofifa.org/players/4/19/238813.png              England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png               Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png              England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png              England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png              England
#
#                                       Flag  Overall  Potential  \
# 18200  https://cdn.sofifa.org/flags/42.png       47         62
# 18201  https://cdn.sofifa.org/flags/25.png       47         68
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# 18205  https://cdn.sofifa.org/flags/14.png       47         66
# 18206  https://cdn.sofifa.org/flags/14.png       46         66
#
#                    Club                                       Club Logo  ...  \
# 18200      Swindon Town   https://cdn.sofifa.org/teams/2/light/1934.png  ...
# 18201      Waterford FC    https://cdn.sofifa.org/teams/2/light/753.png  ...
# 18202   Crewe Alexandra    https://cdn.sofifa.org/teams/2/light/121.png  ...
# 18203    Trelleborgs FF    https://cdn.sofifa.org/teams/2/light/703.png  ...
# 18204  Cambridge United   https://cdn.sofifa.org/teams/2/light/1944.png  ...
# 18205   Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png  ...
# 18206   Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png  ...
#
#       Composure Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  \
# 18200      50.0    15.0            17.0          14.0      11.0        15.0
# 18201      43.0    44.0            47.0          53.0       9.0        10.0
# 18202      45.0    40.0            48.0          47.0      10.0        13.0
# 18203      42.0    22.0            15.0          19.0      10.0         9.0
# 18204      41.0    32.0            13.0          11.0       6.0         5.0
# 18205      46.0    20.0            25.0          27.0      14.0         6.0
# 18206      43.0    40.0            43.0          50.0      10.0        15.0
#
#        GKKicking GKPositioning GKReflexes Release Clause
# 18200       12.0          12.0       11.0          €143K
# 18201        9.0          11.0       13.0          €153K
# 18202        7.0           8.0        9.0          €143K
# 18203        9.0           5.0       12.0          €113K
# 18204       10.0           6.0       13.0          €165K
# 18205       14.0           8.0        9.0          €143K
# 18206        9.0          12.0        9.0          €165K
#
# [7 rows x 88 columns]

# %% [markdown]
# <i>reviews.to_csv("newReviews.csv")</i>

# %%
df1.to_csv("random.csv")

# %% [markdown]
# ### Manipulating the index

# %%
temp = df.set_index('Age')
temp
# Out:
#          ID                Name  \
# Age
# 31   158023            L. Messi
# 33    20801   Cristiano Ronaldo
# 26   190871           Neymar Jr
# 27   193080              De Gea
# 27   192985        K. De Bruyne
# ..      ...                 ...
# 19   238813        J. Lundstram
# 19   243165  N. Christoffersson
# 16   241638           B. Worman
# 17   246268      D. Walker-Rice
# 16   246269           G. Nugent
#
#                                               Photo Nationality  \
# Age
# 31   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 33    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 26   https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 27   https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 27   https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ..                                              ...         ...
# 19   https://cdn.sofifa.org/players/4/19/238813.png     England
# 19   https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 16   https://cdn.sofifa.org/players/4/19/241638.png     England
# 17   https://cdn.sofifa.org/players/4/19/246268.png     England
# 16   https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                     Flag  Overall  Potential  \
# Age
# 31   https://cdn.sofifa.org/flags/52.png       94         94
# 33   https://cdn.sofifa.org/flags/38.png       94         94
# 26   https://cdn.sofifa.org/flags/54.png       92         93
# 27   https://cdn.sofifa.org/flags/45.png       91         93
# 27    https://cdn.sofifa.org/flags/7.png       91         92
# ..                                   ...      ...        ...
# 19   https://cdn.sofifa.org/flags/14.png       47         65
# 19   https://cdn.sofifa.org/flags/46.png       47         63
# 16   https://cdn.sofifa.org/flags/14.png       47         67
# 17   https://cdn.sofifa.org/flags/14.png       47         66
# 16   https://cdn.sofifa.org/flags/14.png       46         66
#
#                     Club                                       Club Logo  \
# Age
# 31          FC Barcelona    https://cdn.sofifa.org/teams/2/light/241.png
# 33              Juventus     https://cdn.sofifa.org/teams/2/light/45.png
# 26   Paris Saint-Germain     https://cdn.sofifa.org/teams/2/light/73.png
# 27     Manchester United     https://cdn.sofifa.org/teams/2/light/11.png
# 27       Manchester City     https://cdn.sofifa.org/teams/2/light/10.png
# ..                   ...                                             ...
# 19       Crewe Alexandra    https://cdn.sofifa.org/teams/2/light/121.png
# 19        Trelleborgs FF    https://cdn.sofifa.org/teams/2/light/703.png
# 16      Cambridge United   https://cdn.sofifa.org/teams/2/light/1944.png
# 17       Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
# 16       Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
#
#        Value  ... Composure  Marking StandingTackle  SlidingTackle  GKDiving  \
# Age           ...
# 31   €110.5M  ...      96.0     33.0           28.0           26.0       6.0
# 33      €77M  ...      95.0     28.0           31.0           23.0       7.0
# 26   €118.5M  ...      94.0     27.0           24.0           33.0       9.0
# 27      €72M  ...      68.0     15.0           21.0           13.0      90.0
# 27     €102M  ...      88.0     68.0           58.0           51.0      15.0
# ..       ...  ...       ...      ...            ...            ...       ...
# 19      €60K  ...      45.0     40.0           48.0           47.0      10.0
# 19      €60K  ...      42.0     22.0           15.0           19.0      10.0
# 16      €60K  ...      41.0     32.0           13.0           11.0       6.0
# 17      €60K  ...      46.0     20.0           25.0           27.0      14.0
# 16      €60K  ...      43.0     40.0           43.0           50.0      10.0
#
#      GKHandling GKKicking GKPositioning GKReflexes Release Clause
# Age
# 31         11.0      15.0          14.0        8.0        €226.5M
# 33         11.0      15.0          14.0       11.0        €127.1M
# 26          9.0      15.0          15.0       11.0        €228.1M
# 27         85.0      87.0          88.0       94.0        €138.6M
# 27         13.0       5.0          10.0       13.0        €196.4M
# ..          ...       ...           ...        ...            ...
# 19         13.0       7.0           8.0        9.0          €143K
# 19          9.0       9.0           5.0       12.0          €113K
# 16          5.0      10.0           6.0       13.0          €165K
# 17          6.0      14.0           8.0        9.0          €143K
# 16         15.0       9.0          12.0        9.0          €165K
#
# [18207 rows x 87 columns]

# %%
temp.reset_index(drop= True, inplace= True)

# %%
temp
# Out:
#            ID                Name  \
# 0      158023            L. Messi
# 1       20801   Cristiano Ronaldo
# 2      190871           Neymar Jr
# 3      193080              De Gea
# 4      192985        K. De Bruyne
# ...       ...                 ...
# 18202  238813        J. Lundstram
# 18203  243165  N. Christoffersson
# 18204  241638           B. Worman
# 18205  246268      D. Walker-Rice
# 18206  246269           G. Nugent
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.org/flags/52.png       94         94
# 1      https://cdn.sofifa.org/flags/38.png       94         94
# 2      https://cdn.sofifa.org/flags/54.png       92         93
# 3      https://cdn.sofifa.org/flags/45.png       91         93
# 4       https://cdn.sofifa.org/flags/7.png       91         92
# ...                                    ...      ...        ...
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# 18205  https://cdn.sofifa.org/flags/14.png       47         66
# 18206  https://cdn.sofifa.org/flags/14.png       46         66
#
#                       Club                                       Club Logo  \
# 0             FC Barcelona    https://cdn.sofifa.org/teams/2/light/241.png
# 1                 Juventus     https://cdn.sofifa.org/teams/2/light/45.png
# 2      Paris Saint-Germain     https://cdn.sofifa.org/teams/2/light/73.png
# 3        Manchester United     https://cdn.sofifa.org/teams/2/light/11.png
# 4          Manchester City     https://cdn.sofifa.org/teams/2/light/10.png
# ...                    ...                                             ...
# 18202      Crewe Alexandra    https://cdn.sofifa.org/teams/2/light/121.png
# 18203       Trelleborgs FF    https://cdn.sofifa.org/teams/2/light/703.png
# 18204     Cambridge United   https://cdn.sofifa.org/teams/2/light/1944.png
# 18205      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
# 18206      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
#
#          Value  ... Composure  Marking StandingTackle  SlidingTackle  \
# 0      €110.5M  ...      96.0     33.0           28.0           26.0
# 1         €77M  ...      95.0     28.0           31.0           23.0
# 2      €118.5M  ...      94.0     27.0           24.0           33.0
# 3         €72M  ...      68.0     15.0           21.0           13.0
# 4        €102M  ...      88.0     68.0           58.0           51.0
# ...        ...  ...       ...      ...            ...            ...
# 18202     €60K  ...      45.0     40.0           48.0           47.0
# 18203     €60K  ...      42.0     22.0           15.0           19.0
# 18204     €60K  ...      41.0     32.0           13.0           11.0
# 18205     €60K  ...      46.0     20.0           25.0           27.0
# 18206     €60K  ...      43.0     40.0           43.0           50.0
#
#        GKDiving  GKHandling GKKicking GKPositioning GKReflexes Release Clause
# 0           6.0        11.0      15.0          14.0        8.0        €226.5M
# 1           7.0        11.0      15.0          14.0       11.0        €127.1M
# 2           9.0         9.0      15.0          15.0       11.0        €228.1M
# 3          90.0        85.0      87.0          88.0       94.0        €138.6M
# 4          15.0        13.0       5.0          10.0       13.0        €196.4M
# ...         ...         ...       ...           ...        ...            ...
# 18202      10.0        13.0       7.0           8.0        9.0          €143K
# 18203      10.0         9.0       9.0           5.0       12.0          €113K
# 18204       6.0         5.0      10.0           6.0       13.0          €165K
# 18205      14.0         6.0      14.0           8.0        9.0          €143K
# 18206      10.0        15.0       9.0          12.0        9.0          €165K
#
# [18207 rows x 87 columns]

# %% [markdown]
# # Accessors

# %% [markdown]
# Columns in a pandas DataFrame is like attribute in objects: book.title -> reviews.country <br>
# or as we did in dictionaries: reviews[ 'country' ] <br>
# either of them is more or less syntactically valid than the other, but the indexing operator [] does have the advantage that it can handle column names with reserved characters in them(eg. "country province") <br>
# to get a single specific value : reviews['country'][(index)]<br><br>
# pandas native accessors: <b>iloc</b> and <b>loc</b>

# %%
df
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.org/flags/52.png       94         94
# 1      https://cdn.sofifa.org/flags/38.png       94         94
# 2      https://cdn.sofifa.org/flags/54.png       92         93
# 3      https://cdn.sofifa.org/flags/45.png       91         93
# 4       https://cdn.sofifa.org/flags/7.png       91         92
# ...                                    ...      ...        ...
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# 18205  https://cdn.sofifa.org/flags/14.png       47         66
# 18206  https://cdn.sofifa.org/flags/14.png       46         66
#
#                       Club                                       Club Logo  \
# 0             FC Barcelona    https://cdn.sofifa.org/teams/2/light/241.png
# 1                 Juventus     https://cdn.sofifa.org/teams/2/light/45.png
# 2      Paris Saint-Germain     https://cdn.sofifa.org/teams/2/light/73.png
# 3        Manchester United     https://cdn.sofifa.org/teams/2/light/11.png
# 4          Manchester City     https://cdn.sofifa.org/teams/2/light/10.png
# ...                    ...                                             ...
# 18202      Crewe Alexandra    https://cdn.sofifa.org/teams/2/light/121.png
# 18203       Trelleborgs FF    https://cdn.sofifa.org/teams/2/light/703.png
# 18204     Cambridge United   https://cdn.sofifa.org/teams/2/light/1944.png
# 18205      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
# 18206      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
#
#        ... Composure Marking  StandingTackle SlidingTackle  GKDiving  \
# 0      ...      96.0    33.0            28.0          26.0       6.0
# 1      ...      95.0    28.0            31.0          23.0       7.0
# 2      ...      94.0    27.0            24.0          33.0       9.0
# 3      ...      68.0    15.0            21.0          13.0      90.0
# 4      ...      88.0    68.0            58.0          51.0      15.0
# ...    ...       ...     ...             ...           ...       ...
# 18202  ...      45.0    40.0            48.0          47.0      10.0
# 18203  ...      42.0    22.0            15.0          19.0      10.0
# 18204  ...      41.0    32.0            13.0          11.0       6.0
# 18205  ...      46.0    20.0            25.0          27.0      14.0
# 18206  ...      43.0    40.0            43.0          50.0      10.0
#
#        GKHandling  GKKicking GKPositioning GKReflexes Release Clause
# 0            11.0       15.0          14.0        8.0        €226.5M
# 1            11.0       15.0          14.0       11.0        €127.1M
# 2             9.0       15.0          15.0       11.0        €228.1M
# 3            85.0       87.0          88.0       94.0        €138.6M
# 4            13.0        5.0          10.0       13.0        €196.4M
# ...           ...        ...           ...        ...            ...
# 18202        13.0        7.0           8.0        9.0          €143K
# 18203         9.0        9.0           5.0       12.0          €113K
# 18204         5.0       10.0           6.0       13.0          €165K
# 18205         6.0       14.0           8.0        9.0          €143K
# 18206        15.0        9.0          12.0        9.0          €165K
#
# [18207 rows x 88 columns]

# %%
df.Age
# Out:
# 0        31
# 1        33
# 2        26
# 3        27
# 4        27
#          ..
# 18202    19
# 18203    19
# 18204    16
# 18205    17
# 18206    16
# Name: Age, Length: 18207, dtype: int64

# %%
df['Age']
# Out:
# 0        31
# 1        33
# 2        26
# 3        27
# 4        27
#          ..
# 18202    19
# 18203    19
# 18204    16
# 18205    17
# 18206    16
# Name: Age, Length: 18207, dtype: int64

# %%
df.Club Logo
# Out:
#   File "C:\Users\MoNam\AppData\Local\Temp/ipykernel_3036/1130443681.py", line 1
#     df.Club Logo
#                ^
# SyntaxError: invalid syntax

# %%
df['Club Logo']
# Out:
# 0          https://cdn.sofifa.org/teams/2/light/241.png
# 1           https://cdn.sofifa.org/teams/2/light/45.png
# 2           https://cdn.sofifa.org/teams/2/light/73.png
# 3           https://cdn.sofifa.org/teams/2/light/11.png
# 4           https://cdn.sofifa.org/teams/2/light/10.png
#                               ...
# 18202      https://cdn.sofifa.org/teams/2/light/121.png
# 18203      https://cdn.sofifa.org/teams/2/light/703.png
# 18204     https://cdn.sofifa.org/teams/2/light/1944.png
# 18205    https://cdn.sofifa.org/teams/2/light/15048.png
# 18206    https://cdn.sofifa.org/teams/2/light/15048.png
# Name: Club Logo, Length: 18207, dtype: object

# %%
df["Nationality"][1606]
# Out:
# 'Iran'

# %%
df['Nationality'][10:20:2]
# Out:
# 10     Poland
# 12    Uruguay
# 14     France
# 16    England
# 18    Germany
# Name: Nationality, dtype: object

# %%
df.Age[100:200:10]
# Out:
# 100    29
# 110    22
# 120    26
# 130    30
# 140    29
# 150    32
# 160    22
# 170    26
# 180    24
# 190    27
# Name: Age, dtype: int64

# %%
total = df.shape[0]
france_players = 0
for x in df.Nationality:
    if x == 'France':
        france_players += 1

round(france_players*100/total, 2)
# Out:
# 5.02

# %% [markdown]
# #### Index-based selection (iloc)

# %% [markdown]
# Both loc and iloc are row-first, column-second. This is the opposite of what we do in native Python, which is column-first, row-second.

# %%
df.iloc[8, 1:5]
# Out:
# Name                                             Sergio Ramos
# Age                                                        32
# Photo          https://cdn.sofifa.org/players/4/19/155862.png
# Nationality                                             Spain
# Name: 8, dtype: object

# %%
df.iloc[1]
# Out:
# ID                                                        20801
# Name                                          Cristiano Ronaldo
# Age                                                          33
# Photo             https://cdn.sofifa.org/players/4/19/20801.png
# Nationality                                            Portugal
#                                       ...
# GKHandling                                                 11.0
# GKKicking                                                  15.0
# GKPositioning                                              14.0
# GKReflexes                                                 11.0
# Release Clause                                          €127.1M
# Name: 1, Length: 88, dtype: object

# %%
df.iloc[0:6, [0,1,2,4]]
# Out:
#        ID               Name  Age Nationality
# 0  158023           L. Messi   31   Argentina
# 1   20801  Cristiano Ronaldo   33    Portugal
# 2  190871          Neymar Jr   26      Brazil
# 3  193080             De Gea   27       Spain
# 4  192985       K. De Bruyne   27     Belgium
# 5  183277          E. Hazard   27     Belgium

# %%
df.iloc[0:6, ['Age','Nationality']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3036/2381877823.py in <module>
# ----> 1 df.iloc[0:6, ['Age','Nationality']]
#
# C:\python37\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# C:\python37\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
#
# C:\python37\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     752         for i, k in enumerate(key):
#     753             try:
# --> 754                 self._validate_key(k, i)
#     755             except ValueError as err:
#     756                 raise ValueError(
#
# C:\python37\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1418             # check that the key has a numeric dtype
#    1419             if not is_numeric_dtype(arr.dtype):
# -> 1420                 raise IndexError(f".iloc requires numeric indexers, got {arr}")
#    1421
#    1422             # check that the key does not exceed the maximum size of the index
#
# IndexError: .iloc requires numeric indexers, got ['Age' 'Nationality']

# %%
df.iloc[1800:1806][['Age','Nationality']]
# Out:
#       Age    Nationality
# 1800   18        England
# 1801   26         Brazil
# 1802   28          Spain
# 1803   31  United States
# 1804   28         Greece
# 1805   28         Brazil

# %%
df.iloc[2090, [1,4]]
# Out:
# Name           S. Ghoddos
# Nationality          Iran
# Name: 2090, dtype: object

# %%
df.iloc[50:61, [1]]
# Out:
#               Name
# 50      D. Mertens
# 51   J. Vertonghen
# 52       M. Hamšík
# 53      I. Rakitić
# 54           Piqué
# 55         L. Sané
# 56  Bernardo Silva
# 57         Ederson
# 58         S. Mané
# 59     V. van Dijk
# 60     R. Sterling

# %%
df.iloc[1:6, 1:5]
# Out:
#                 Name  Age                                           Photo  \
# 1  Cristiano Ronaldo   33   https://cdn.sofifa.org/players/4/19/20801.png
# 2          Neymar Jr   26  https://cdn.sofifa.org/players/4/19/190871.png
# 3             De Gea   27  https://cdn.sofifa.org/players/4/19/193080.png
# 4       K. De Bruyne   27  https://cdn.sofifa.org/players/4/19/192985.png
# 5          E. Hazard   27  https://cdn.sofifa.org/players/4/19/183277.png
#
#   Nationality
# 1    Portugal
# 2      Brazil
# 3       Spain
# 4     Belgium
# 5     Belgium

# %%
df.iloc[[1,10,100,1000,10000], [1,4,86]]
# Out:
#                     Name Nationality  GKReflexes
# 1      Cristiano Ronaldo    Portugal        11.0
# 10        R. Lewandowski      Poland        10.0
# 100          Diego Costa       Spain        11.0
# 1000             A. Poli       Italy         5.0
# 10000        J. Haugaard     Denmark        66.0

# %%
df.iloc[range(20,60,5), range(80,87)]
# Out:
#     StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 20            86.0           80.0       5.0         8.0       13.0
# 25            34.0           32.0      13.0         5.0        7.0
# 30            64.0           51.0      10.0         8.0       12.0
# 35            85.0           86.0      12.0         5.0        5.0
# 40            10.0           13.0      87.0        86.0       69.0
# 45            70.0           68.0       5.0         6.0        2.0
# 50            40.0           40.0       7.0        10.0        8.0
# 55            32.0           35.0       8.0        12.0        9.0
#
#     GKPositioning  GKReflexes
# 20            9.0        13.0
# 25           11.0         6.0
# 30           15.0         6.0
# 35            5.0         9.0
# 40           89.0        89.0
# 45            4.0         3.0
# 50           10.0         4.0
# 55            9.0        14.0

# %% [markdown]
# #### Label-based selection (loc)

# %% [markdown]
# label-based selection. In this paradigm, it's the data index value, not its position, which matters.

# %%
df
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.org/flags/52.png       94         94
# 1      https://cdn.sofifa.org/flags/38.png       94         94
# 2      https://cdn.sofifa.org/flags/54.png       92         93
# 3      https://cdn.sofifa.org/flags/45.png       91         93
# 4       https://cdn.sofifa.org/flags/7.png       91         92
# ...                                    ...      ...        ...
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# 18205  https://cdn.sofifa.org/flags/14.png       47         66
# 18206  https://cdn.sofifa.org/flags/14.png       46         66
#
#                       Club                                       Club Logo  \
# 0             FC Barcelona    https://cdn.sofifa.org/teams/2/light/241.png
# 1                 Juventus     https://cdn.sofifa.org/teams/2/light/45.png
# 2      Paris Saint-Germain     https://cdn.sofifa.org/teams/2/light/73.png
# 3        Manchester United     https://cdn.sofifa.org/teams/2/light/11.png
# 4          Manchester City     https://cdn.sofifa.org/teams/2/light/10.png
# ...                    ...                                             ...
# 18202      Crewe Alexandra    https://cdn.sofifa.org/teams/2/light/121.png
# 18203       Trelleborgs FF    https://cdn.sofifa.org/teams/2/light/703.png
# 18204     Cambridge United   https://cdn.sofifa.org/teams/2/light/1944.png
# 18205      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
# 18206      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
#
#        ... Composure Marking  StandingTackle SlidingTackle  GKDiving  \
# 0      ...      96.0    33.0            28.0          26.0       6.0
# 1      ...      95.0    28.0            31.0          23.0       7.0
# 2      ...      94.0    27.0            24.0          33.0       9.0
# 3      ...      68.0    15.0            21.0          13.0      90.0
# 4      ...      88.0    68.0            58.0          51.0      15.0
# ...    ...       ...     ...             ...           ...       ...
# 18202  ...      45.0    40.0            48.0          47.0      10.0
# 18203  ...      42.0    22.0            15.0          19.0      10.0
# 18204  ...      41.0    32.0            13.0          11.0       6.0
# 18205  ...      46.0    20.0            25.0          27.0      14.0
# 18206  ...      43.0    40.0            43.0          50.0      10.0
#
#        GKHandling  GKKicking GKPositioning GKReflexes Release Clause
# 0            11.0       15.0          14.0        8.0        €226.5M
# 1            11.0       15.0          14.0       11.0        €127.1M
# 2             9.0       15.0          15.0       11.0        €228.1M
# 3            85.0       87.0          88.0       94.0        €138.6M
# 4            13.0        5.0          10.0       13.0        €196.4M
# ...           ...        ...           ...        ...            ...
# 18202        13.0        7.0           8.0        9.0          €143K
# 18203         9.0        9.0           5.0       12.0          €113K
# 18204         5.0       10.0           6.0       13.0          €165K
# 18205         6.0       14.0           8.0        9.0          €143K
# 18206        15.0        9.0          12.0        9.0          €165K
#
# [18207 rows x 88 columns]

# %%
df.loc[10]
# Out:
# ID                                                        188545
# Name                                              R. Lewandowski
# Age                                                           29
# Photo             https://cdn.sofifa.org/players/4/19/188545.png
# Nationality                                               Poland
#                                        ...
# GKHandling                                                   6.0
# GKKicking                                                   12.0
# GKPositioning                                                8.0
# GKReflexes                                                  10.0
# Release Clause                                           €127.1M
# Name: 10, Length: 88, dtype: object

# %%
df.loc[2:7]
# Out:
#        ID          Name  Age                                           Photo  \
# 2  190871     Neymar Jr   26  https://cdn.sofifa.org/players/4/19/190871.png
# 3  193080        De Gea   27  https://cdn.sofifa.org/players/4/19/193080.png
# 4  192985  K. De Bruyne   27  https://cdn.sofifa.org/players/4/19/192985.png
# 5  183277     E. Hazard   27  https://cdn.sofifa.org/players/4/19/183277.png
# 6  177003     L. Modrić   32  https://cdn.sofifa.org/players/4/19/177003.png
# 7  176580     L. Suárez   31  https://cdn.sofifa.org/players/4/19/176580.png
#
#   Nationality                                 Flag  Overall  Potential  \
# 2      Brazil  https://cdn.sofifa.org/flags/54.png       92         93
# 3       Spain  https://cdn.sofifa.org/flags/45.png       91         93
# 4     Belgium   https://cdn.sofifa.org/flags/7.png       91         92
# 5     Belgium   https://cdn.sofifa.org/flags/7.png       91         91
# 6     Croatia  https://cdn.sofifa.org/flags/10.png       91         91
# 7     Uruguay  https://cdn.sofifa.org/flags/60.png       91         91
#
#                   Club                                     Club Logo  ...  \
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  ...
# 3    Manchester United   https://cdn.sofifa.org/teams/2/light/11.png  ...
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png  ...
# 5              Chelsea    https://cdn.sofifa.org/teams/2/light/5.png  ...
# 6          Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png  ...
# 7         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
#
#   Composure Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  \
# 2      94.0    27.0            24.0          33.0       9.0         9.0
# 3      68.0    15.0            21.0          13.0      90.0        85.0
# 4      88.0    68.0            58.0          51.0      15.0        13.0
# 5      91.0    34.0            27.0          22.0      11.0        12.0
# 6      84.0    60.0            76.0          73.0      13.0         9.0
# 7      85.0    62.0            45.0          38.0      27.0        25.0
#
#    GKKicking GKPositioning GKReflexes Release Clause
# 2       15.0          15.0       11.0        €228.1M
# 3       87.0          88.0       94.0        €138.6M
# 4        5.0          10.0       13.0        €196.4M
# 5        6.0           8.0        8.0        €172.1M
# 6        7.0          14.0        9.0        €137.4M
# 7       31.0          33.0       37.0          €164M
#
# [6 rows x 88 columns]

# %%
df.loc[2:7, ['Name', 'Nationality']]
# Out:
#            Name Nationality
# 2     Neymar Jr      Brazil
# 3        De Gea       Spain
# 4  K. De Bruyne     Belgium
# 5     E. Hazard     Belgium
# 6     L. Modrić     Croatia
# 7     L. Suárez     Uruguay

# %%
df.loc[2:10, 'Name':'Wage']
# Out:
#               Name  Age                                           Photo  \
# 2        Neymar Jr   26  https://cdn.sofifa.org/players/4/19/190871.png
# 3           De Gea   27  https://cdn.sofifa.org/players/4/19/193080.png
# 4     K. De Bruyne   27  https://cdn.sofifa.org/players/4/19/192985.png
# 5        E. Hazard   27  https://cdn.sofifa.org/players/4/19/183277.png
# 6        L. Modrić   32  https://cdn.sofifa.org/players/4/19/177003.png
# 7        L. Suárez   31  https://cdn.sofifa.org/players/4/19/176580.png
# 8     Sergio Ramos   32  https://cdn.sofifa.org/players/4/19/155862.png
# 9         J. Oblak   25  https://cdn.sofifa.org/players/4/19/200389.png
# 10  R. Lewandowski   29  https://cdn.sofifa.org/players/4/19/188545.png
#
#    Nationality                                 Flag  Overall  Potential  \
# 2       Brazil  https://cdn.sofifa.org/flags/54.png       92         93
# 3        Spain  https://cdn.sofifa.org/flags/45.png       91         93
# 4      Belgium   https://cdn.sofifa.org/flags/7.png       91         92
# 5      Belgium   https://cdn.sofifa.org/flags/7.png       91         91
# 6      Croatia  https://cdn.sofifa.org/flags/10.png       91         91
# 7      Uruguay  https://cdn.sofifa.org/flags/60.png       91         91
# 8        Spain  https://cdn.sofifa.org/flags/45.png       91         91
# 9     Slovenia  https://cdn.sofifa.org/flags/44.png       90         93
# 10      Poland  https://cdn.sofifa.org/flags/37.png       90         90
#
#                    Club                                     Club Logo  \
# 2   Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png
# 3     Manchester United   https://cdn.sofifa.org/teams/2/light/11.png
# 4       Manchester City   https://cdn.sofifa.org/teams/2/light/10.png
# 5               Chelsea    https://cdn.sofifa.org/teams/2/light/5.png
# 6           Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png
# 7          FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png
# 8           Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png
# 9       Atlético Madrid  https://cdn.sofifa.org/teams/2/light/240.png
# 10    FC Bayern München   https://cdn.sofifa.org/teams/2/light/21.png
#
#       Value   Wage
# 2   €118.5M  €290K
# 3      €72M  €260K
# 4     €102M  €355K
# 5      €93M  €340K
# 6      €67M  €420K
# 7      €80M  €455K
# 8      €51M  €380K
# 9      €68M   €94K
# 10     €77M  €205K

# %%
df.iloc[2:10]
# Out:
#        ID          Name  Age                                           Photo  \
# 2  190871     Neymar Jr   26  https://cdn.sofifa.org/players/4/19/190871.png
# 3  193080        De Gea   27  https://cdn.sofifa.org/players/4/19/193080.png
# 4  192985  K. De Bruyne   27  https://cdn.sofifa.org/players/4/19/192985.png
# 5  183277     E. Hazard   27  https://cdn.sofifa.org/players/4/19/183277.png
# 6  177003     L. Modrić   32  https://cdn.sofifa.org/players/4/19/177003.png
# 7  176580     L. Suárez   31  https://cdn.sofifa.org/players/4/19/176580.png
# 8  155862  Sergio Ramos   32  https://cdn.sofifa.org/players/4/19/155862.png
# 9  200389      J. Oblak   25  https://cdn.sofifa.org/players/4/19/200389.png
#
#   Nationality                                 Flag  Overall  Potential  \
# 2      Brazil  https://cdn.sofifa.org/flags/54.png       92         93
# 3       Spain  https://cdn.sofifa.org/flags/45.png       91         93
# 4     Belgium   https://cdn.sofifa.org/flags/7.png       91         92
# 5     Belgium   https://cdn.sofifa.org/flags/7.png       91         91
# 6     Croatia  https://cdn.sofifa.org/flags/10.png       91         91
# 7     Uruguay  https://cdn.sofifa.org/flags/60.png       91         91
# 8       Spain  https://cdn.sofifa.org/flags/45.png       91         91
# 9    Slovenia  https://cdn.sofifa.org/flags/44.png       90         93
#
#                   Club                                     Club Logo  ...  \
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  ...
# 3    Manchester United   https://cdn.sofifa.org/teams/2/light/11.png  ...
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png  ...
# 5              Chelsea    https://cdn.sofifa.org/teams/2/light/5.png  ...
# 6          Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png  ...
# 7         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
# 8          Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png  ...
# 9      Atlético Madrid  https://cdn.sofifa.org/teams/2/light/240.png  ...
#
#   Composure Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  \
# 2      94.0    27.0            24.0          33.0       9.0         9.0
# 3      68.0    15.0            21.0          13.0      90.0        85.0
# 4      88.0    68.0            58.0          51.0      15.0        13.0
# 5      91.0    34.0            27.0          22.0      11.0        12.0
# 6      84.0    60.0            76.0          73.0      13.0         9.0
# 7      85.0    62.0            45.0          38.0      27.0        25.0
# 8      82.0    87.0            92.0          91.0      11.0         8.0
# 9      70.0    27.0            12.0          18.0      86.0        92.0
#
#    GKKicking GKPositioning GKReflexes Release Clause
# 2       15.0          15.0       11.0        €228.1M
# 3       87.0          88.0       94.0        €138.6M
# 4        5.0          10.0       13.0        €196.4M
# 5        6.0           8.0        8.0        €172.1M
# 6        7.0          14.0        9.0        €137.4M
# 7       31.0          33.0       37.0          €164M
# 8        9.0           7.0       11.0        €104.6M
# 9       78.0          88.0       89.0        €144.5M
#
# [8 rows x 88 columns]

# %%
df.loc[[1,10,100,1000], ['Name', 'Age', 'Wage']]
# Out:
#                    Name  Age   Wage
# 1     Cristiano Ronaldo   33  €405K
# 10       R. Lewandowski   29  €205K
# 100         Diego Costa   29  €100K
# 1000            A. Poli   28   €34K

# %%
tempdf = df.set_index('Name')
tempdf
# Out:
#                         ID  Age  \
# Name
# L. Messi            158023   31
# Cristiano Ronaldo    20801   33
# Neymar Jr           190871   26
# De Gea              193080   27
# K. De Bruyne        192985   27
# ...                    ...  ...
# J. Lundstram        238813   19
# N. Christoffersson  243165   19
# B. Worman           241638   16
# D. Walker-Rice      246268   17
# G. Nugent           246269   16
#
#                                                              Photo  \
# Name
# L. Messi            https://cdn.sofifa.org/players/4/19/158023.png
# Cristiano Ronaldo    https://cdn.sofifa.org/players/4/19/20801.png
# Neymar Jr           https://cdn.sofifa.org/players/4/19/190871.png
# De Gea              https://cdn.sofifa.org/players/4/19/193080.png
# K. De Bruyne        https://cdn.sofifa.org/players/4/19/192985.png
# ...                                                            ...
# J. Lundstram        https://cdn.sofifa.org/players/4/19/238813.png
# N. Christoffersson  https://cdn.sofifa.org/players/4/19/243165.png
# B. Worman           https://cdn.sofifa.org/players/4/19/241638.png
# D. Walker-Rice      https://cdn.sofifa.org/players/4/19/246268.png
# G. Nugent           https://cdn.sofifa.org/players/4/19/246269.png
#
#                    Nationality                                 Flag  Overall  \
# Name
# L. Messi             Argentina  https://cdn.sofifa.org/flags/52.png       94
# Cristiano Ronaldo     Portugal  https://cdn.sofifa.org/flags/38.png       94
# Neymar Jr               Brazil  https://cdn.sofifa.org/flags/54.png       92
# De Gea                   Spain  https://cdn.sofifa.org/flags/45.png       91
# K. De Bruyne           Belgium   https://cdn.sofifa.org/flags/7.png       91
# ...                        ...                                  ...      ...
# J. Lundstram           England  https://cdn.sofifa.org/flags/14.png       47
# N. Christoffersson      Sweden  https://cdn.sofifa.org/flags/46.png       47
# B. Worman              England  https://cdn.sofifa.org/flags/14.png       47
# D. Walker-Rice         England  https://cdn.sofifa.org/flags/14.png       47
# G. Nugent              England  https://cdn.sofifa.org/flags/14.png       46
#
#                     Potential                 Club  \
# Name
# L. Messi                   94         FC Barcelona
# Cristiano Ronaldo          94             Juventus
# Neymar Jr                  93  Paris Saint-Germain
# De Gea                     93    Manchester United
# K. De Bruyne               92      Manchester City
# ...                       ...                  ...
# J. Lundstram               65      Crewe Alexandra
# N. Christoffersson         63       Trelleborgs FF
# B. Worman                  67     Cambridge United
# D. Walker-Rice             66      Tranmere Rovers
# G. Nugent                  66      Tranmere Rovers
#
#                                                          Club Logo    Value  \
# Name
# L. Messi              https://cdn.sofifa.org/teams/2/light/241.png  €110.5M
# Cristiano Ronaldo      https://cdn.sofifa.org/teams/2/light/45.png     €77M
# Neymar Jr              https://cdn.sofifa.org/teams/2/light/73.png  €118.5M
# De Gea                 https://cdn.sofifa.org/teams/2/light/11.png     €72M
# K. De Bruyne           https://cdn.sofifa.org/teams/2/light/10.png    €102M
# ...                                                            ...      ...
# J. Lundstram          https://cdn.sofifa.org/teams/2/light/121.png     €60K
# N. Christoffersson    https://cdn.sofifa.org/teams/2/light/703.png     €60K
# B. Worman            https://cdn.sofifa.org/teams/2/light/1944.png     €60K
# D. Walker-Rice      https://cdn.sofifa.org/teams/2/light/15048.png     €60K
# G. Nugent           https://cdn.sofifa.org/teams/2/light/15048.png     €60K
#
#                     ... Composure  Marking StandingTackle  SlidingTackle  \
# Name                ...
# L. Messi            ...      96.0     33.0           28.0           26.0
# Cristiano Ronaldo   ...      95.0     28.0           31.0           23.0
# Neymar Jr           ...      94.0     27.0           24.0           33.0
# De Gea              ...      68.0     15.0           21.0           13.0
# K. De Bruyne        ...      88.0     68.0           58.0           51.0
# ...                 ...       ...      ...            ...            ...
# J. Lundstram        ...      45.0     40.0           48.0           47.0
# N. Christoffersson  ...      42.0     22.0           15.0           19.0
# B. Worman           ...      41.0     32.0           13.0           11.0
# D. Walker-Rice      ...      46.0     20.0           25.0           27.0
# G. Nugent           ...      43.0     40.0           43.0           50.0
#
#                     GKDiving  GKHandling GKKicking GKPositioning GKReflexes  \
# Name
# L. Messi                 6.0        11.0      15.0          14.0        8.0
# Cristiano Ronaldo        7.0        11.0      15.0          14.0       11.0
# Neymar Jr                9.0         9.0      15.0          15.0       11.0
# De Gea                  90.0        85.0      87.0          88.0       94.0
# K. De Bruyne            15.0        13.0       5.0          10.0       13.0
# ...                      ...         ...       ...           ...        ...
# J. Lundstram            10.0        13.0       7.0           8.0        9.0
# N. Christoffersson      10.0         9.0       9.0           5.0       12.0
# B. Worman                6.0         5.0      10.0           6.0       13.0
# D. Walker-Rice          14.0         6.0      14.0           8.0        9.0
# G. Nugent               10.0        15.0       9.0          12.0        9.0
#
#                    Release Clause
# Name
# L. Messi                  €226.5M
# Cristiano Ronaldo         €127.1M
# Neymar Jr                 €228.1M
# De Gea                    €138.6M
# K. De Bruyne              €196.4M
# ...                           ...
# J. Lundstram                €143K
# N. Christoffersson          €113K
# B. Worman                   €165K
# D. Walker-Rice              €143K
# G. Nugent                   €165K
#
# [18207 rows x 87 columns]

# %%
tempdf.iloc[2:10, [1,3,6,7]]
# Out:
#               Age Nationality  Potential                 Club
# Name
# Neymar Jr      26      Brazil         93  Paris Saint-Germain
# De Gea         27       Spain         93    Manchester United
# K. De Bruyne   27     Belgium         92      Manchester City
# E. Hazard      27     Belgium         91              Chelsea
# L. Modrić      32     Croatia         91          Real Madrid
# L. Suárez      31     Uruguay         91         FC Barcelona
# Sergio Ramos   32       Spain         91          Real Madrid
# J. Oblak       25    Slovenia         93      Atlético Madrid

# %%
tempdf.loc[2:10, 'Name':'Wage']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3036/729635655.py in <module>
# ----> 1 tempdf.loc[2:10, 'Name':'Wage']
#
# C:\python37\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# C:\python37\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# C:\python37\lib\site-packages\pandas\core\indexing.py in _getitem_tuple_same_dim(self, tup)
#     804                 continue
#     805
# --> 806             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     807             # We should never have retval.ndim < self.ndim, as that should
#     808             #  be handled by the _getitem_lowerdim call above.
#
# C:\python37\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1140         if isinstance(key, slice):
#    1141             self._validate_key(key, axis)
# -> 1142             return self._get_slice_axis(key, axis=axis)
#    1143         elif com.is_bool_indexer(key):
#    1144             return self._getbool_axis(key, axis=axis)
#
# C:\python37\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1174
#    1175         labels = obj._get_axis(axis)
# -> 1176         indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1177
#    1178         if isinstance(indexer, slice):
#
# C:\python37\lib\site-packages\pandas\core\indexes\base.py in slice_indexer(self, start, end, step, kind)
#    5683         slice(1, 3, None)
#    5684         """
# -> 5685         start_slice, end_slice = self.slice_locs(start, end, step=step)
#    5686
#    5687         # return a slice
#
# C:\python37\lib\site-packages\pandas\core\indexes\base.py in slice_locs(self, start, end, step, kind)
#    5885         start_slice = None
#    5886         if start is not None:
# -> 5887             start_slice = self.get_slice_bound(start, "left")
#    5888         if start_slice is None:
#    5889             start_slice = 0
#
# C:\python37\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    5795         # For datetime indices label may be a string that has to be converted
#    5796         # to datetime boundary according to its resolution.
# -> 5797         label = self._maybe_cast_slice_bound(label, side)
#    5798
#    5799         # we need to look up the label
#
# C:\python37\lib\site-packages\pandas\core\indexes\base.py in _maybe_cast_slice_bound(self, label, side, kind)
#    5747         # reject them, if index does not contain label
#    5748         if (is_float(label) or is_integer(label)) and label not in self._values:
# -> 5749             raise self._invalid_indexer("slice", label)
#    5750
#    5751         return label
#
# TypeError: cannot do slice indexing on Index with these indexers [2] of type int

# %%
tempdf.loc['L. Messi':'De Gea', 'Overall':'Wage']
# Out:
#                    Overall  Potential                 Club  \
# Name
# L. Messi                94         94         FC Barcelona
# Cristiano Ronaldo       94         94             Juventus
# Neymar Jr               92         93  Paris Saint-Germain
# De Gea                  91         93    Manchester United
#
#                                                       Club Logo    Value  \
# Name
# L. Messi           https://cdn.sofifa.org/teams/2/light/241.png  €110.5M
# Cristiano Ronaldo   https://cdn.sofifa.org/teams/2/light/45.png     €77M
# Neymar Jr           https://cdn.sofifa.org/teams/2/light/73.png  €118.5M
# De Gea              https://cdn.sofifa.org/teams/2/light/11.png     €72M
#
#                     Wage
# Name
# L. Messi           €565K
# Cristiano Ronaldo  €405K
# Neymar Jr          €290K
# De Gea             €260K

# %% [markdown]
# Note: iloc uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded, where loc is inclusive.

# %%
tempdf
# Out:
#                         ID  Age  \
# Name
# L. Messi            158023   31
# Cristiano Ronaldo    20801   33
# Neymar Jr           190871   26
# De Gea              193080   27
# K. De Bruyne        192985   27
# ...                    ...  ...
# J. Lundstram        238813   19
# N. Christoffersson  243165   19
# B. Worman           241638   16
# D. Walker-Rice      246268   17
# G. Nugent           246269   16
#
#                                                              Photo  \
# Name
# L. Messi            https://cdn.sofifa.org/players/4/19/158023.png
# Cristiano Ronaldo    https://cdn.sofifa.org/players/4/19/20801.png
# Neymar Jr           https://cdn.sofifa.org/players/4/19/190871.png
# De Gea              https://cdn.sofifa.org/players/4/19/193080.png
# K. De Bruyne        https://cdn.sofifa.org/players/4/19/192985.png
# ...                                                            ...
# J. Lundstram        https://cdn.sofifa.org/players/4/19/238813.png
# N. Christoffersson  https://cdn.sofifa.org/players/4/19/243165.png
# B. Worman           https://cdn.sofifa.org/players/4/19/241638.png
# D. Walker-Rice      https://cdn.sofifa.org/players/4/19/246268.png
# G. Nugent           https://cdn.sofifa.org/players/4/19/246269.png
#
#                    Nationality                                 Flag  Overall  \
# Name
# L. Messi             Argentina  https://cdn.sofifa.org/flags/52.png       94
# Cristiano Ronaldo     Portugal  https://cdn.sofifa.org/flags/38.png       94
# Neymar Jr               Brazil  https://cdn.sofifa.org/flags/54.png       92
# De Gea                   Spain  https://cdn.sofifa.org/flags/45.png       91
# K. De Bruyne           Belgium   https://cdn.sofifa.org/flags/7.png       91
# ...                        ...                                  ...      ...
# J. Lundstram           England  https://cdn.sofifa.org/flags/14.png       47
# N. Christoffersson      Sweden  https://cdn.sofifa.org/flags/46.png       47
# B. Worman              England  https://cdn.sofifa.org/flags/14.png       47
# D. Walker-Rice         England  https://cdn.sofifa.org/flags/14.png       47
# G. Nugent              England  https://cdn.sofifa.org/flags/14.png       46
#
#                     Potential                 Club  \
# Name
# L. Messi                   94         FC Barcelona
# Cristiano Ronaldo          94             Juventus
# Neymar Jr                  93  Paris Saint-Germain
# De Gea                     93    Manchester United
# K. De Bruyne               92      Manchester City
# ...                       ...                  ...
# J. Lundstram               65      Crewe Alexandra
# N. Christoffersson         63       Trelleborgs FF
# B. Worman                  67     Cambridge United
# D. Walker-Rice             66      Tranmere Rovers
# G. Nugent                  66      Tranmere Rovers
#
#                                                          Club Logo    Value  \
# Name
# L. Messi              https://cdn.sofifa.org/teams/2/light/241.png  €110.5M
# Cristiano Ronaldo      https://cdn.sofifa.org/teams/2/light/45.png     €77M
# Neymar Jr              https://cdn.sofifa.org/teams/2/light/73.png  €118.5M
# De Gea                 https://cdn.sofifa.org/teams/2/light/11.png     €72M
# K. De Bruyne           https://cdn.sofifa.org/teams/2/light/10.png    €102M
# ...                                                            ...      ...
# J. Lundstram          https://cdn.sofifa.org/teams/2/light/121.png     €60K
# N. Christoffersson    https://cdn.sofifa.org/teams/2/light/703.png     €60K
# B. Worman            https://cdn.sofifa.org/teams/2/light/1944.png     €60K
# D. Walker-Rice      https://cdn.sofifa.org/teams/2/light/15048.png     €60K
# G. Nugent           https://cdn.sofifa.org/teams/2/light/15048.png     €60K
#
#                     ... Composure  Marking StandingTackle  SlidingTackle  \
# Name                ...
# L. Messi            ...      96.0     33.0           28.0           26.0
# Cristiano Ronaldo   ...      95.0     28.0           31.0           23.0
# Neymar Jr           ...      94.0     27.0           24.0           33.0
# De Gea              ...      68.0     15.0           21.0           13.0
# K. De Bruyne        ...      88.0     68.0           58.0           51.0
# ...                 ...       ...      ...            ...            ...
# J. Lundstram        ...      45.0     40.0           48.0           47.0
# N. Christoffersson  ...      42.0     22.0           15.0           19.0
# B. Worman           ...      41.0     32.0           13.0           11.0
# D. Walker-Rice      ...      46.0     20.0           25.0           27.0
# G. Nugent           ...      43.0     40.0           43.0           50.0
#
#                     GKDiving  GKHandling GKKicking GKPositioning GKReflexes  \
# Name
# L. Messi                 6.0        11.0      15.0          14.0        8.0
# Cristiano Ronaldo        7.0        11.0      15.0          14.0       11.0
# Neymar Jr                9.0         9.0      15.0          15.0       11.0
# De Gea                  90.0        85.0      87.0          88.0       94.0
# K. De Bruyne            15.0        13.0       5.0          10.0       13.0
# ...                      ...         ...       ...           ...        ...
# J. Lundstram            10.0        13.0       7.0           8.0        9.0
# N. Christoffersson      10.0         9.0       9.0           5.0       12.0
# B. Worman                6.0         5.0      10.0           6.0       13.0
# D. Walker-Rice          14.0         6.0      14.0           8.0        9.0
# G. Nugent               10.0        15.0       9.0          12.0        9.0
#
#                    Release Clause
# Name
# L. Messi                  €226.5M
# Cristiano Ronaldo         €127.1M
# Neymar Jr                 €228.1M
# De Gea                    €138.6M
# K. De Bruyne              €196.4M
# ...                           ...
# J. Lundstram                €143K
# N. Christoffersson          €113K
# B. Worman                   €165K
# D. Walker-Rice              €143K
# G. Nugent                   €165K
#
# [18207 rows x 87 columns]

# %%
tempdf.set_index('Age')
# Out:
#          ID                                           Photo Nationality  \
# Age
# 31   158023  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 33    20801   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 26   190871  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 27   193080  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 27   192985  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ..      ...                                             ...         ...
# 19   238813  https://cdn.sofifa.org/players/4/19/238813.png     England
# 19   243165  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 16   241638  https://cdn.sofifa.org/players/4/19/241638.png     England
# 17   246268  https://cdn.sofifa.org/players/4/19/246268.png     England
# 16   246269  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                     Flag  Overall  Potential  \
# Age
# 31   https://cdn.sofifa.org/flags/52.png       94         94
# 33   https://cdn.sofifa.org/flags/38.png       94         94
# 26   https://cdn.sofifa.org/flags/54.png       92         93
# 27   https://cdn.sofifa.org/flags/45.png       91         93
# 27    https://cdn.sofifa.org/flags/7.png       91         92
# ..                                   ...      ...        ...
# 19   https://cdn.sofifa.org/flags/14.png       47         65
# 19   https://cdn.sofifa.org/flags/46.png       47         63
# 16   https://cdn.sofifa.org/flags/14.png       47         67
# 17   https://cdn.sofifa.org/flags/14.png       47         66
# 16   https://cdn.sofifa.org/flags/14.png       46         66
#
#                     Club                                       Club Logo  \
# Age
# 31          FC Barcelona    https://cdn.sofifa.org/teams/2/light/241.png
# 33              Juventus     https://cdn.sofifa.org/teams/2/light/45.png
# 26   Paris Saint-Germain     https://cdn.sofifa.org/teams/2/light/73.png
# 27     Manchester United     https://cdn.sofifa.org/teams/2/light/11.png
# 27       Manchester City     https://cdn.sofifa.org/teams/2/light/10.png
# ..                   ...                                             ...
# 19       Crewe Alexandra    https://cdn.sofifa.org/teams/2/light/121.png
# 19        Trelleborgs FF    https://cdn.sofifa.org/teams/2/light/703.png
# 16      Cambridge United   https://cdn.sofifa.org/teams/2/light/1944.png
# 17       Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
# 16       Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
#
#        Value   Wage  ...  Composure Marking  StandingTackle  SlidingTackle  \
# Age                  ...
# 31   €110.5M  €565K  ...       96.0    33.0            28.0           26.0
# 33      €77M  €405K  ...       95.0    28.0            31.0           23.0
# 26   €118.5M  €290K  ...       94.0    27.0            24.0           33.0
# 27      €72M  €260K  ...       68.0    15.0            21.0           13.0
# 27     €102M  €355K  ...       88.0    68.0            58.0           51.0
# ..       ...    ...  ...        ...     ...             ...            ...
# 19      €60K    €1K  ...       45.0    40.0            48.0           47.0
# 19      €60K    €1K  ...       42.0    22.0            15.0           19.0
# 16      €60K    €1K  ...       41.0    32.0            13.0           11.0
# 17      €60K    €1K  ...       46.0    20.0            25.0           27.0
# 16      €60K    €1K  ...       43.0    40.0            43.0           50.0
#
#      GKDiving GKHandling GKKicking GKPositioning GKReflexes  Release Clause
# Age
# 31        6.0       11.0      15.0          14.0        8.0         €226.5M
# 33        7.0       11.0      15.0          14.0       11.0         €127.1M
# 26        9.0        9.0      15.0          15.0       11.0         €228.1M
# 27       90.0       85.0      87.0          88.0       94.0         €138.6M
# 27       15.0       13.0       5.0          10.0       13.0         €196.4M
# ..        ...        ...       ...           ...        ...             ...
# 19       10.0       13.0       7.0           8.0        9.0           €143K
# 19       10.0        9.0       9.0           5.0       12.0           €113K
# 16        6.0        5.0      10.0           6.0       13.0           €165K
# 17       14.0        6.0      14.0           8.0        9.0           €143K
# 16       10.0       15.0       9.0          12.0        9.0           €165K
#
# [18207 rows x 86 columns]

# %%
index = list(range(tempdf.shape[0]))
tempdf['index'] = index

# %%
tempdf.set_index('index')
# Out:
#            ID  Age                                           Photo  \
# index
# 0      158023   31  https://cdn.sofifa.org/players/4/19/158023.png
# 1       20801   33   https://cdn.sofifa.org/players/4/19/20801.png
# 2      190871   26  https://cdn.sofifa.org/players/4/19/190871.png
# 3      193080   27  https://cdn.sofifa.org/players/4/19/193080.png
# 4      192985   27  https://cdn.sofifa.org/players/4/19/192985.png
# ...       ...  ...                                             ...
# 18202  238813   19  https://cdn.sofifa.org/players/4/19/238813.png
# 18203  243165   19  https://cdn.sofifa.org/players/4/19/243165.png
# 18204  241638   16  https://cdn.sofifa.org/players/4/19/241638.png
# 18205  246268   17  https://cdn.sofifa.org/players/4/19/246268.png
# 18206  246269   16  https://cdn.sofifa.org/players/4/19/246269.png
#
#       Nationality                                 Flag  Overall  Potential  \
# index
# 0       Argentina  https://cdn.sofifa.org/flags/52.png       94         94
# 1        Portugal  https://cdn.sofifa.org/flags/38.png       94         94
# 2          Brazil  https://cdn.sofifa.org/flags/54.png       92         93
# 3           Spain  https://cdn.sofifa.org/flags/45.png       91         93
# 4         Belgium   https://cdn.sofifa.org/flags/7.png       91         92
# ...           ...                                  ...      ...        ...
# 18202     England  https://cdn.sofifa.org/flags/14.png       47         65
# 18203      Sweden  https://cdn.sofifa.org/flags/46.png       47         63
# 18204     England  https://cdn.sofifa.org/flags/14.png       47         67
# 18205     England  https://cdn.sofifa.org/flags/14.png       47         66
# 18206     England  https://cdn.sofifa.org/flags/14.png       46         66
#
#                       Club                                       Club Logo  \
# index
# 0             FC Barcelona    https://cdn.sofifa.org/teams/2/light/241.png
# 1                 Juventus     https://cdn.sofifa.org/teams/2/light/45.png
# 2      Paris Saint-Germain     https://cdn.sofifa.org/teams/2/light/73.png
# 3        Manchester United     https://cdn.sofifa.org/teams/2/light/11.png
# 4          Manchester City     https://cdn.sofifa.org/teams/2/light/10.png
# ...                    ...                                             ...
# 18202      Crewe Alexandra    https://cdn.sofifa.org/teams/2/light/121.png
# 18203       Trelleborgs FF    https://cdn.sofifa.org/teams/2/light/703.png
# 18204     Cambridge United   https://cdn.sofifa.org/teams/2/light/1944.png
# 18205      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
# 18206      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
#
#          Value  ... Composure  Marking StandingTackle  SlidingTackle  \
# index           ...
# 0      €110.5M  ...      96.0     33.0           28.0           26.0
# 1         €77M  ...      95.0     28.0           31.0           23.0
# 2      €118.5M  ...      94.0     27.0           24.0           33.0
# 3         €72M  ...      68.0     15.0           21.0           13.0
# 4        €102M  ...      88.0     68.0           58.0           51.0
# ...        ...  ...       ...      ...            ...            ...
# 18202     €60K  ...      45.0     40.0           48.0           47.0
# 18203     €60K  ...      42.0     22.0           15.0           19.0
# 18204     €60K  ...      41.0     32.0           13.0           11.0
# 18205     €60K  ...      46.0     20.0           25.0           27.0
# 18206     €60K  ...      43.0     40.0           43.0           50.0
#
#        GKDiving  GKHandling GKKicking GKPositioning GKReflexes Release Clause
# index
# 0           6.0        11.0      15.0          14.0        8.0        €226.5M
# 1           7.0        11.0      15.0          14.0       11.0        €127.1M
# 2           9.0         9.0      15.0          15.0       11.0        €228.1M
# 3          90.0        85.0      87.0          88.0       94.0        €138.6M
# 4          15.0        13.0       5.0          10.0       13.0        €196.4M
# ...         ...         ...       ...           ...        ...            ...
# 18202      10.0        13.0       7.0           8.0        9.0          €143K
# 18203      10.0         9.0       9.0           5.0       12.0          €113K
# 18204       6.0         5.0      10.0           6.0       13.0          €165K
# 18205      14.0         6.0      14.0           8.0        9.0          €143K
# 18206      10.0        15.0       9.0          12.0        9.0          €165K
#
# [18207 rows x 87 columns]

# %%
df1 = tempdf.reset_index(drop= True, inplace=True)
type(df1)
# Out:
# NoneType

# %%
tempdf
# Out:
#            ID  Age                                           Photo  \
# 0      158023   31  https://cdn.sofifa.org/players/4/19/158023.png
# 1       20801   33   https://cdn.sofifa.org/players/4/19/20801.png
# 2      190871   26  https://cdn.sofifa.org/players/4/19/190871.png
# 3      193080   27  https://cdn.sofifa.org/players/4/19/193080.png
# 4      192985   27  https://cdn.sofifa.org/players/4/19/192985.png
# ...       ...  ...                                             ...
# 18202  238813   19  https://cdn.sofifa.org/players/4/19/238813.png
# 18203  243165   19  https://cdn.sofifa.org/players/4/19/243165.png
# 18204  241638   16  https://cdn.sofifa.org/players/4/19/241638.png
# 18205  246268   17  https://cdn.sofifa.org/players/4/19/246268.png
# 18206  246269   16  https://cdn.sofifa.org/players/4/19/246269.png
#
#       Nationality                                 Flag  Overall  Potential  \
# 0       Argentina  https://cdn.sofifa.org/flags/52.png       94         94
# 1        Portugal  https://cdn.sofifa.org/flags/38.png       94         94
# 2          Brazil  https://cdn.sofifa.org/flags/54.png       92         93
# 3           Spain  https://cdn.sofifa.org/flags/45.png       91         93
# 4         Belgium   https://cdn.sofifa.org/flags/7.png       91         92
# ...           ...                                  ...      ...        ...
# 18202     England  https://cdn.sofifa.org/flags/14.png       47         65
# 18203      Sweden  https://cdn.sofifa.org/flags/46.png       47         63
# 18204     England  https://cdn.sofifa.org/flags/14.png       47         67
# 18205     England  https://cdn.sofifa.org/flags/14.png       47         66
# 18206     England  https://cdn.sofifa.org/flags/14.png       46         66
#
#                       Club                                       Club Logo  \
# 0             FC Barcelona    https://cdn.sofifa.org/teams/2/light/241.png
# 1                 Juventus     https://cdn.sofifa.org/teams/2/light/45.png
# 2      Paris Saint-Germain     https://cdn.sofifa.org/teams/2/light/73.png
# 3        Manchester United     https://cdn.sofifa.org/teams/2/light/11.png
# 4          Manchester City     https://cdn.sofifa.org/teams/2/light/10.png
# ...                    ...                                             ...
# 18202      Crewe Alexandra    https://cdn.sofifa.org/teams/2/light/121.png
# 18203       Trelleborgs FF    https://cdn.sofifa.org/teams/2/light/703.png
# 18204     Cambridge United   https://cdn.sofifa.org/teams/2/light/1944.png
# 18205      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
# 18206      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
#
#          Value  ... Composure  Marking StandingTackle  SlidingTackle  \
# 0      €110.5M  ...      96.0     33.0           28.0           26.0
# 1         €77M  ...      95.0     28.0           31.0           23.0
# 2      €118.5M  ...      94.0     27.0           24.0           33.0
# 3         €72M  ...      68.0     15.0           21.0           13.0
# 4        €102M  ...      88.0     68.0           58.0           51.0
# ...        ...  ...       ...      ...            ...            ...
# 18202     €60K  ...      45.0     40.0           48.0           47.0
# 18203     €60K  ...      42.0     22.0           15.0           19.0
# 18204     €60K  ...      41.0     32.0           13.0           11.0
# 18205     €60K  ...      46.0     20.0           25.0           27.0
# 18206     €60K  ...      43.0     40.0           43.0           50.0
#
#        GKDiving  GKHandling GKKicking GKPositioning GKReflexes Release Clause
# 0           6.0        11.0      15.0          14.0        8.0        €226.5M
# 1           7.0        11.0      15.0          14.0       11.0        €127.1M
# 2           9.0         9.0      15.0          15.0       11.0        €228.1M
# 3          90.0        85.0      87.0          88.0       94.0        €138.6M
# 4          15.0        13.0       5.0          10.0       13.0        €196.4M
# ...         ...         ...       ...           ...        ...            ...
# 18202      10.0        13.0       7.0           8.0        9.0          €143K
# 18203      10.0         9.0       9.0           5.0       12.0          €113K
# 18204       6.0         5.0      10.0           6.0       13.0          €165K
# 18205      14.0         6.0      14.0           8.0        9.0          €143K
# 18206      10.0        15.0       9.0          12.0        9.0          €165K
#
# [18207 rows x 87 columns]

# %%
df1 = df1.reset_index()
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3036/3675396004.py in <module>
# ----> 1 df1 = df1.reset_index()
#       2 df1
#
# C:\python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\python37\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5797                     )
#    5798
# -> 5799                 new_obj.insert(0, name, level_values)
#    5800
#    5801         new_obj.index = new_index
#
# C:\python37\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    4412         if not allow_duplicates and column in self.columns:
#    4413             # Should this be a different kind of error??
# -> 4414             raise ValueError(f"cannot insert {column}, already exists")
#    4415         if not isinstance(loc, int):
#    4416             raise TypeError("loc must be int")
#
# ValueError: cannot insert level_0, already exists

# %%
tempdf.reset_index(inplace=True)

# %%
tempdf.set_index('ID', inplace=True)
tempdf
# Out:
#                       Name  Age  \
# ID
# 158023            L. Messi   31
# 20801    Cristiano Ronaldo   33
# 190871           Neymar Jr   26
# 193080              De Gea   27
# 192985        K. De Bruyne   27
# ...                    ...  ...
# 238813        J. Lundstram   19
# 243165  N. Christoffersson   19
# 241638           B. Worman   16
# 246268      D. Walker-Rice   17
# 246269           G. Nugent   16
#
#                                                  Photo Nationality  \
# ID
# 158023  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 20801    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 190871  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 193080  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 192985  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                                ...         ...
# 238813  https://cdn.sofifa.org/players/4/19/238813.png     England
# 243165  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 241638  https://cdn.sofifa.org/players/4/19/241638.png     England
# 246268  https://cdn.sofifa.org/players/4/19/246268.png     England
# 246269  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                        Flag  Overall  Potential  \
# ID
# 158023  https://cdn.sofifa.org/flags/52.png       94         94
# 20801   https://cdn.sofifa.org/flags/38.png       94         94
# 190871  https://cdn.sofifa.org/flags/54.png       92         93
# 193080  https://cdn.sofifa.org/flags/45.png       91         93
# 192985   https://cdn.sofifa.org/flags/7.png       91         92
# ...                                     ...      ...        ...
# 238813  https://cdn.sofifa.org/flags/14.png       47         65
# 243165  https://cdn.sofifa.org/flags/46.png       47         63
# 241638  https://cdn.sofifa.org/flags/14.png       47         67
# 246268  https://cdn.sofifa.org/flags/14.png       47         66
# 246269  https://cdn.sofifa.org/flags/14.png       46         66
#
#                        Club                                       Club Logo  \
# ID
# 158023         FC Barcelona    https://cdn.sofifa.org/teams/2/light/241.png
# 20801              Juventus     https://cdn.sofifa.org/teams/2/light/45.png
# 190871  Paris Saint-Germain     https://cdn.sofifa.org/teams/2/light/73.png
# 193080    Manchester United     https://cdn.sofifa.org/teams/2/light/11.png
# 192985      Manchester City     https://cdn.sofifa.org/teams/2/light/10.png
# ...                     ...                                             ...
# 238813      Crewe Alexandra    https://cdn.sofifa.org/teams/2/light/121.png
# 243165       Trelleborgs FF    https://cdn.sofifa.org/teams/2/light/703.png
# 241638     Cambridge United   https://cdn.sofifa.org/teams/2/light/1944.png
# 246268      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
# 246269      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
#
#           Value  ... Composure  Marking StandingTackle  SlidingTackle  \
# ID               ...
# 158023  €110.5M  ...      96.0     33.0           28.0           26.0
# 20801      €77M  ...      95.0     28.0           31.0           23.0
# 190871  €118.5M  ...      94.0     27.0           24.0           33.0
# 193080     €72M  ...      68.0     15.0           21.0           13.0
# 192985    €102M  ...      88.0     68.0           58.0           51.0
# ...         ...  ...       ...      ...            ...            ...
# 238813     €60K  ...      45.0     40.0           48.0           47.0
# 243165     €60K  ...      42.0     22.0           15.0           19.0
# 241638     €60K  ...      41.0     32.0           13.0           11.0
# 246268     €60K  ...      46.0     20.0           25.0           27.0
# 246269     €60K  ...      43.0     40.0           43.0           50.0
#
#         GKDiving  GKHandling GKKicking GKPositioning GKReflexes Release Clause
# ID
# 158023       6.0        11.0      15.0          14.0        8.0        €226.5M
# 20801        7.0        11.0      15.0          14.0       11.0        €127.1M
# 190871       9.0         9.0      15.0          15.0       11.0        €228.1M
# 193080      90.0        85.0      87.0          88.0       94.0        €138.6M
# 192985      15.0        13.0       5.0          10.0       13.0        €196.4M
# ...          ...         ...       ...           ...        ...            ...
# 238813      10.0        13.0       7.0           8.0        9.0          €143K
# 243165      10.0         9.0       9.0           5.0       12.0          €113K
# 241638       6.0         5.0      10.0           6.0       13.0          €165K
# 246268      14.0         6.0      14.0           8.0        9.0          €143K
# 246269      10.0        15.0       9.0          12.0        9.0          €165K
#
# [18207 rows x 87 columns]

# %%
tempdf.reset_index(inplace=True)
tempdf
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.org/flags/52.png       94         94
# 1      https://cdn.sofifa.org/flags/38.png       94         94
# 2      https://cdn.sofifa.org/flags/54.png       92         93
# 3      https://cdn.sofifa.org/flags/45.png       91         93
# 4       https://cdn.sofifa.org/flags/7.png       91         92
# ...                                    ...      ...        ...
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# 18205  https://cdn.sofifa.org/flags/14.png       47         66
# 18206  https://cdn.sofifa.org/flags/14.png       46         66
#
#                       Club                                       Club Logo  \
# 0             FC Barcelona    https://cdn.sofifa.org/teams/2/light/241.png
# 1                 Juventus     https://cdn.sofifa.org/teams/2/light/45.png
# 2      Paris Saint-Germain     https://cdn.sofifa.org/teams/2/light/73.png
# 3        Manchester United     https://cdn.sofifa.org/teams/2/light/11.png
# 4          Manchester City     https://cdn.sofifa.org/teams/2/light/10.png
# ...                    ...                                             ...
# 18202      Crewe Alexandra    https://cdn.sofifa.org/teams/2/light/121.png
# 18203       Trelleborgs FF    https://cdn.sofifa.org/teams/2/light/703.png
# 18204     Cambridge United   https://cdn.sofifa.org/teams/2/light/1944.png
# 18205      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
# 18206      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
#
#        ... Composure Marking  StandingTackle SlidingTackle  GKDiving  \
# 0      ...      96.0    33.0            28.0          26.0       6.0
# 1      ...      95.0    28.0            31.0          23.0       7.0
# 2      ...      94.0    27.0            24.0          33.0       9.0
# 3      ...      68.0    15.0            21.0          13.0      90.0
# 4      ...      88.0    68.0            58.0          51.0      15.0
# ...    ...       ...     ...             ...           ...       ...
# 18202  ...      45.0    40.0            48.0          47.0      10.0
# 18203  ...      42.0    22.0            15.0          19.0      10.0
# 18204  ...      41.0    32.0            13.0          11.0       6.0
# 18205  ...      46.0    20.0            25.0          27.0      14.0
# 18206  ...      43.0    40.0            43.0          50.0      10.0
#
#        GKHandling  GKKicking GKPositioning GKReflexes Release Clause
# 0            11.0       15.0          14.0        8.0        €226.5M
# 1            11.0       15.0          14.0       11.0        €127.1M
# 2             9.0       15.0          15.0       11.0        €228.1M
# 3            85.0       87.0          88.0       94.0        €138.6M
# 4            13.0        5.0          10.0       13.0        €196.4M
# ...           ...        ...           ...        ...            ...
# 18202        13.0        7.0           8.0        9.0          €143K
# 18203         9.0        9.0           5.0       12.0          €113K
# 18204         5.0       10.0           6.0       13.0          €165K
# 18205         6.0       14.0           8.0        9.0          €143K
# 18206        15.0        9.0          12.0        9.0          €165K
#
# [18207 rows x 88 columns]

# %%
df1 = df.loc[0:14, ['Name', 'Age', 'Nationality', 'Overall', 'Wage']]
df1
# Out:
#                  Name  Age Nationality  Overall   Wage
# 0            L. Messi   31   Argentina       94  €565K
# 1   Cristiano Ronaldo   33    Portugal       94  €405K
# 2           Neymar Jr   26      Brazil       92  €290K
# 3              De Gea   27       Spain       91  €260K
# 4        K. De Bruyne   27     Belgium       91  €355K
# 5           E. Hazard   27     Belgium       91  €340K
# 6           L. Modrić   32     Croatia       91  €420K
# 7           L. Suárez   31     Uruguay       91  €455K
# 8        Sergio Ramos   32       Spain       91  €380K
# 9            J. Oblak   25    Slovenia       90   €94K
# 10     R. Lewandowski   29      Poland       90  €205K
# 11           T. Kroos   28     Germany       90  €355K
# 12           D. Godín   32     Uruguay       90  €125K
# 13        David Silva   32       Spain       90  €285K
# 14           N. Kanté   27      France       89  €225K

# %%
df1 = df1[['Age', 'Name', 'Wage', 'Overall',  'Nationality']]
df1
# Out:
#     Age               Name   Wage  Overall Nationality
# 0    31           L. Messi  €565K       94   Argentina
# 1    33  Cristiano Ronaldo  €405K       94    Portugal
# 2    26          Neymar Jr  €290K       92      Brazil
# 3    27             De Gea  €260K       91       Spain
# 4    27       K. De Bruyne  €355K       91     Belgium
# 5    27          E. Hazard  €340K       91     Belgium
# 6    32          L. Modrić  €420K       91     Croatia
# 7    31          L. Suárez  €455K       91     Uruguay
# 8    32       Sergio Ramos  €380K       91       Spain
# 9    25           J. Oblak   €94K       90    Slovenia
# 10   29     R. Lewandowski  €205K       90      Poland
# 11   28           T. Kroos  €355K       90     Germany
# 12   32           D. Godín  €125K       90     Uruguay
# 13   32        David Silva  €285K       90       Spain
# 14   27           N. Kanté  €225K       89      France

# %%
ages = df1['Age'].copy()
df1['Age'] = df1['Overall']
df1['Overall'] = ages
df1
# Out:
#     Age               Name   Wage  Overall Nationality
# 0    94           L. Messi  €565K       31   Argentina
# 1    94  Cristiano Ronaldo  €405K       33    Portugal
# 2    92          Neymar Jr  €290K       26      Brazil
# 3    91             De Gea  €260K       27       Spain
# 4    91       K. De Bruyne  €355K       27     Belgium
# 5    91          E. Hazard  €340K       27     Belgium
# 6    91          L. Modrić  €420K       32     Croatia
# 7    91          L. Suárez  €455K       31     Uruguay
# 8    91       Sergio Ramos  €380K       32       Spain
# 9    90           J. Oblak   €94K       25    Slovenia
# 10   90     R. Lewandowski  €205K       29      Poland
# 11   90           T. Kroos  €355K       28     Germany
# 12   90           D. Godín  €125K       32     Uruguay
# 13   90        David Silva  €285K       32       Spain
# 14   89           N. Kanté  €225K       27      France

# %%
df1.rename(columns={'Age':'Overall', "Overall":"Age"}, inplace=True)
df1
# Out:
#     Overall               Name   Wage  Age Nationality
# 0        94           L. Messi  €565K   31   Argentina
# 1        94  Cristiano Ronaldo  €405K   33    Portugal
# 2        92          Neymar Jr  €290K   26      Brazil
# 3        91             De Gea  €260K   27       Spain
# 4        91       K. De Bruyne  €355K   27     Belgium
# 5        91          E. Hazard  €340K   27     Belgium
# 6        91          L. Modrić  €420K   32     Croatia
# 7        91          L. Suárez  €455K   31     Uruguay
# 8        91       Sergio Ramos  €380K   32       Spain
# 9        90           J. Oblak   €94K   25    Slovenia
# 10       90     R. Lewandowski  €205K   29      Poland
# 11       90           T. Kroos  €355K   28     Germany
# 12       90           D. Godín  €125K   32     Uruguay
# 13       90        David Silva  €285K   32       Spain
# 14       89           N. Kanté  €225K   27      France

# %% [markdown]
# ### Conditional selection

# %%
df['Age'] > 30
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Name: Age, Length: 18207, dtype: bool

# %%
df.loc[df['Age'] > 30]
# Out:
#            ID               Name  Age  \
# 0      158023           L. Messi   31
# 1       20801  Cristiano Ronaldo   33
# 6      177003          L. Modrić   32
# 7      176580          L. Suárez   31
# 8      155862       Sergio Ramos   32
# ...       ...                ...  ...
# 17842  182461          Zhou Ting   39
# 17866  232676           N. Hatta   32
# 18043  237917          A. Suzuki   31
# 18171  237746        Y. Uchimura   33
# 18183   53748      K. Pilkington   44
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 6      https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7      https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# 8      https://cdn.sofifa.org/players/4/19/155862.png       Spain
# ...                                               ...         ...
# 17842  https://cdn.sofifa.org/players/4/19/182461.png    China PR
# 17866  https://cdn.sofifa.org/players/4/19/232676.png       Japan
# 18043  https://cdn.sofifa.org/players/4/19/237917.png       Japan
# 18171  https://cdn.sofifa.org/players/4/19/237746.png       Japan
# 18183   https://cdn.sofifa.org/players/4/19/53748.png     England
#
#                                        Flag  Overall  Potential  \
# 0       https://cdn.sofifa.org/flags/52.png       94         94
# 1       https://cdn.sofifa.org/flags/38.png       94         94
# 6       https://cdn.sofifa.org/flags/10.png       91         91
# 7       https://cdn.sofifa.org/flags/60.png       91         91
# 8       https://cdn.sofifa.org/flags/45.png       91         91
# ...                                     ...      ...        ...
# 17842  https://cdn.sofifa.org/flags/155.png       52         52
# 17866  https://cdn.sofifa.org/flags/163.png       52         52
# 18043  https://cdn.sofifa.org/flags/163.png       50         50
# 18171  https://cdn.sofifa.org/flags/163.png       48         48
# 18183   https://cdn.sofifa.org/flags/14.png       48         48
#
#                              Club  \
# 0                    FC Barcelona
# 1                        Juventus
# 6                     Real Madrid
# 7                    FC Barcelona
# 8                     Real Madrid
# ...                           ...
# 17842            Dalian YiFang FC
# 17866                Júbilo Iwata
# 18043         Yokohama F. Marinos
# 18171  Hokkaido Consadole Sapporo
# 18183            Cambridge United
#
#                                              Club Logo  ... Composure Marking  \
# 0         https://cdn.sofifa.org/teams/2/light/241.png  ...      96.0    33.0
# 1          https://cdn.sofifa.org/teams/2/light/45.png  ...      95.0    28.0
# 6         https://cdn.sofifa.org/teams/2/light/243.png  ...      84.0    60.0
# 7         https://cdn.sofifa.org/teams/2/light/241.png  ...      85.0    62.0
# 8         https://cdn.sofifa.org/teams/2/light/243.png  ...      82.0    87.0
# ...                                                ...  ...       ...     ...
# 17842  https://cdn.sofifa.org/teams/2/light/112378.png  ...      52.0    17.0
# 17866  https://cdn.sofifa.org/teams/2/light/101144.png  ...      24.0    30.0
# 18043  https://cdn.sofifa.org/teams/2/light/101151.png  ...      31.0    13.0
# 18171  https://cdn.sofifa.org/teams/2/light/112444.png  ...      62.0    45.0
# 18183    https://cdn.sofifa.org/teams/2/light/1944.png  ...      56.0    15.0
#
#        StandingTackle SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0                28.0          26.0       6.0        11.0       15.0
# 1                31.0          23.0       7.0        11.0       15.0
# 6                76.0          73.0      13.0         9.0        7.0
# 7                45.0          38.0      27.0        25.0       31.0
# 8                92.0          91.0      11.0         8.0        9.0
# ...               ...           ...       ...         ...        ...
# 17842            45.0          44.0      10.0        12.0        7.0
# 17866            12.0          13.0      54.0        48.0       45.0
# 18043            10.0          14.0      49.0        48.0       54.0
# 18171            48.0          42.0      13.0        15.0        7.0
# 18183            15.0          13.0      45.0        48.0       44.0
#
#       GKPositioning GKReflexes Release Clause
# 0              14.0        8.0        €226.5M
# 1              14.0       11.0        €127.1M
# 6              14.0        9.0        €137.4M
# 7              33.0       37.0          €164M
# 8               7.0       11.0        €104.6M
# ...             ...        ...            ...
# 17842          15.0        6.0           €22K
# 17866          52.0       54.0           €38K
# 18043          52.0       54.0           €25K
# 18171          15.0       15.0           €25K
# 18183          49.0       46.0            NaN
#
# [2582 rows x 88 columns]

# %% [markdown]
# <b> isin()</b> and <b>isnull() / notnull()</b>

# %% [markdown]
# # Summary Functions

# %% [markdown]
#         describe()       mean()         unique()        value_counts()

# %%
df.GKKicking.mean()

# %% [markdown]
# # Maps

# %% [markdown]
#   <b>map()</b> and <b>apply()</b>

# %% [markdown]
# The function you pass to map() should expect a single value from the Series <br>map() returns a new Series where all the values have been transformed by your function.

# %% [markdown]
# apply() is the equivalent method if we want to transform a whole DataFrame by calling a custom method on each row.<br>
# These operators are faster than map() or apply() because they uses speed ups built into pandas. All of the standard Python operators (>, <, ==, and so on) work in this manner.
#
# However, they are not as flexible as map() or apply(), which can do more advanced things, like applying conditional logic, which cannot be done with addition and subtraction alone.
